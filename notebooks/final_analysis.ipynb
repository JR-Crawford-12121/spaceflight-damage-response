# %% [markdown]
# # Final analysis — Spaceflight DNA Damage Response Classifier
#
# Thin notebook wrapper: the authoritative pipeline is `python main.py` at the repo root.
# Use this notebook for exploration once tables exist under `outputs/tables/`.

# %%
import sys
from pathlib import Path

ROOT = Path("..").resolve()
sys.path.insert(0, str(ROOT / "src"))

import pandas as pd

pathway = pd.read_csv(ROOT / "outputs" / "tables" / "pathway_scores.csv")
topgenes = pd.read_csv(ROOT / "outputs" / "tables" / "top_damage_response_genes.csv")
pathway.head(), topgenes.head()
